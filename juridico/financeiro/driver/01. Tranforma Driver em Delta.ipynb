# %%
# %run "/Workspace/Jurídico/funcao_tratamento_fechamento/common_functions"

# %%
dbutils.widgets.text("dt_driver", "", "Data driver")

# %%
dt_driver = dbutils.widgets.get("dt_driver")

caminho = f'/Volumes/databox/juridico_comum/arquivos/bases_drivers/ACOMPANHAMENTO_DESP_JUDICIAIS_{dt_driver}.xlsx'

base_driver_trabalhista = read_excel(caminho, "'PBI'!A1:KG1048576")

base_driver_trabalhista = adjust_column_names(base_driver_trabalhista)

base_driver_trabalhista = base_driver_trabalhista.fillna('')

base_driver_trabalhista = adjust_column_names(base_driver_trabalhista)

# %%
display(base_driver_trabalhista)

base_driver_trabalhista.schema
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MES_FECHAMENTO</th><th>AREA</th><th>TIPO</th><th>COD_REAL</th><th>SLD_PROV_TOTAL_EMPRESA_QTD</th><th>SLD_PROV_TOTAL_EMPRESA_NOVOS_QTD</th><th>SLD_PROV_TOTAL_EMPRESA_LEGADO_QTD</th><th>C7</th><th>PROC_COM_PROV_TOTAL_EMPRESA_QTD</th><th>PROC_COM_PROV_TOTAL_EMPRESA_NOVOS_QTD</th><th>PROC_COM_PROV_TOTAL_EMPRESA_LEGADO_QTD</th><th>C11</th><th>ENTR_QTD</th><th>ENTR_AC_QTD</th><th>ENTR_DEF_QTD</th><th>ENTR_REAT_QTD</th><th>ENTR_REAT_SEM_EST_QTD</th><th>ENTR_REAT_COM_EST_QTD</th><th>C18</th><th>ENTR_%AC</th><th>ENTR_%DEF</th><th>SAIDA_QTD</th><th>SAIDA_SEM_ONUS_QTD</th><th>SAIDA_AC_AV_QTD</th><th>SAIDA_AC_PARC_QTD</th><th>SAIDA_COND_AV_QTD</th><th>SAIDA_COND_PARC_QTD</th><th>SAIDA_COND_PARC_PARC_MOV_QTD</th><th>SAIDA_COND_PARC_INCONTR_MOV_QTD</th><th>C29</th><th>C30</th><th>ADIC_REV_QTD</th><th>ADIC_QTD</th><th>ADIC_AGING_QTD</th><th>ADIC_MUD_CALC_QTD</th><th>ADIC_DEF_PARA_AC_QTD</th><th>ADIC_EXEC_QTD</th><th>ADIC_SOLV_PARA_INSOLV_QTD</th><th>ADIC_MUD_FASE_QTD</th><th>ADIC_FALTA_DOC_QTD</th><th>ADIC_ENTR_NAOIDENT</th><th>ADIC_COL_QTD</th><th>ADIC_INSS_QTD</th><th>REV_QTD</th><th>REV_AGING_QTD</th><th>REV_MUD_CALC_QTD</th><th>REV_AC_VZ_PARA_DEF_QTD</th><th>REV_EXEC_QTD</th><th>REV_SOLV_PARA_INSOLV_QTD</th><th>REV_MUD_FASE_QTD</th><th>REV_INSS_QTD</th><th>PGTO_QTD</th><th>PGTO_QTD_AC</th><th>PGTO_QTD_AC_PARC</th><th>PGTO_QTD_COND</th><th>PGTO_QTD_COND_PARC</th><th>PGTO_QTD_LIB_DEP_JUD</th><th>PGTO_QTD_PEN</th><th>PGTO_QTD_IMP</th><th>CRED_QTD</th><th>CRED_CI_QTD</th><th>CRED_OTH_GPA_QTD</th><th>CRED_OTH_FK_QTD</th><th>CRED_OTH_CNOVA_QTD</th><th>CRED_TERCEIROS</th><th>CRED_OTH_NAO_RECON_FK_QTD</th><th>C66</th><th>ENCERRADOS_QTD</th><th>ENCERRADOS_NOVOS_QTD</th><th>ENCERRADOS_LEGADO_QTD</th><th>C70</th><th>ENTR_VLR</th><th>ENTR_NOVOS_VLR</th><th>ENTR_REAT_VLR</th><th>C74</th><th>SAIDA_VLR</th><th>SAIDA_SEM_ONUS_VLR</th><th>SAIDA_AC_AV_VLR</th><th>SAIDA_AC_PARC_VLR</th><th>SAIDA_AC_PARC_MOV_VLR</th><th>SAIDA_AC_PARC_PROV_VLR</th><th>SAIDA_COND_AV_VLR</th><th>SAIDA_COND_PARC_VLR</th><th>SAIDA_COND_PARC_PARC_VLR</th><th>SAIDA_COND_PARC_INCONTR_VLR</th><th>SAIDA_COND_PARC_PROV_VLR</th><th>SAIDA_COND_INCONTR_VLR</th><th>SAIDA_GAR_PEN_VLR</th><th>C88</th><th>ADIC_REV_VLR</th><th>ADIC_VLR</th><th>ADIC_AGING_VLR</th><th>ADIC_MUD_CALC_VLR</th><th>ADIC_DEF_PARA_AC_VLR</th><th>ADIC_EXEC_VLR</th><th>ADIC_SOLV_PARA_INSOLV_VLR</th><th>ADIC_MUD_FASE_VLR</th><th>ADIC_FALTA_DOC_VLR</th><th>ADIC_NAO_IDENT_VLR</th><th>ADIC_COL_VLR</th><th>ADIC_INSS_VLR</th><th>REV_VLR</th><th>REV_AGING_VLR</th><th>REV_MUD_CALC_VLR</th><th>REV_AC_VZ_PARA_DEF_VLR</th><th>REV_EXEC_VLR</th><th>REV_SOLV_PARA_INSOLV_VLR</th><th>REV_MUD_FASE_VLR</th><th>REV_INSS_VLR</th><th>REV_ACO_PAR_VLR</th><th>REV_COND_PAR_VLR</th><th>REV_COND_INC_VLR</th><th>REV_GARPEN_VLR</th><th>REV_IMP_VLR</th><th>REV_ENTR_EMPRE_VLR</th><th>REV_NAO_IDENT_VLR</th><th>PGTO_VLR</th><th>PGTO_AC_AV_VLR</th><th>PGTO_AC_PARC_VLR</th><th>PGTO_COND_AV_VLR</th><th>PGTO_COND_PARC_VLR</th><th>PGTO_COND_PARC_PARC_VLR</th><th>PGTO_COND_INCONTR_PARC_VLR</th><th>PGTO_LIB_DEP_JUD_VLR</th><th>PGTO_PEN_VLR</th><th>PGTO_IMP_VLR</th><th>CRED_VLR</th><th>CRED_CI_VLR</th><th>CRED_OTH_GPA_VLR</th><th>CRED_OTH_FK_VLR</th><th>CRED_OTH_CNOVA_VLR</th><th>CRED_TERC_VLR</th><th>CRED_OTH_NAO_RECON_FK_VLR</th><th>CRED_GPA_VLR</th><th>CRED_CNOVA_VLR</th><th>CTA_REC</th><th>CTA_REC_GPA</th><th>CTA_REC_CBEP</th><th>CTA_REC_CNOVA</th><th>CTA_REC_AJ_DEP_JUD</th><th>C140</th><th>PGTO_ENCERRADOS_VLR</th><th>PGTO_ENCERRADOS_NOVOS_VLR</th><th>PGTO_ENCERRADOS_LEGADO_VLR</th><th>C144</th><th>C145</th><th>IMPACTO_SEM_AT_MONET_VLR</th><th>C147</th><th>IMPACTO_SEM_AT_MONET_DRE_VLR</th><th>IMPACTO_SEM_AT_MONET_VLR_VS_ORCA</th><th>IMPACTO_SEM_AT_MONET_VLR_VS_ANO_ANT</th><th>C151</th><th>AT_MONET_VLR</th><th>IMPACTO_COM_AT_MONET_VLR</th><th>VS_ORCA_IMPACTO_COM_AT_MONET</th><th>VS_ANO_ANT_IMPACTO_COM_AT_MONET</th><th>IMPACTO_COM_AT_MONET_ ...
# StructType([StructField('MES_FECHAMENTO', TimestampType(), True), StructField('AREA', StringType(), False), StructField('TIPO', StringType(), False), StructField('COD_REAL', StringType(), False), StructField('SLD_PROV_TOTAL_EMPRESA_QTD', DoubleType(), True), StructField('SLD_PROV_TOTAL_EMPRESA_NOVOS_QTD', DoubleType(), True), StructField('SLD_PROV_TOTAL_EMPRESA_LEGADO_QTD', DoubleType(), True), StructField('C7', DoubleType(), True), StructField('PROC_COM_PROV_TOTAL_EMPRESA_QTD', DoubleType(), True), StructField('PROC_COM_PROV_TOTAL_EMPRESA_NOVOS_QTD', DoubleType(), True), StructField('PROC_COM_PROV_TOTAL_EMPRESA_LEGADO_QTD', DoubleType(), True), StructField('C11', DoubleType(), True), StructField('ENTR_QTD', DoubleType(), True), StructField('ENTR_AC_QTD', DoubleType(), True), StructField('ENTR_DEF_QTD', DoubleType(), True), StructField('ENTR_REAT_QTD', DoubleType(), True), StructField('ENTR_REAT_SEM_EST_QTD', DoubleType(), True), StructField('ENTR_REAT_COM_EST_QTD', DoubleType(), True), StructField('C18', DoubleType(), True), StructField('ENTR_%AC', DoubleType(), True), StructField('ENTR_%DEF', DoubleType(), True), StructField('SAIDA_QTD', DoubleType(), True), StructField('SAIDA_SEM_ONUS_QTD', DoubleType(), True), StructField('SAIDA_AC_AV_QTD', DoubleType(), True), StructField('SAIDA_AC_PARC_QTD', DoubleType(), True), StructField('SAIDA_COND_AV_QTD', DoubleType(), True), StructField('SAIDA_COND_PARC_QTD', DoubleType(), True), StructField('SAIDA_COND_PARC_PARC_MOV_QTD', DoubleType(), True), StructField('SAIDA_COND_PARC_INCONTR_MOV_QTD', DoubleType(), True), StructField('C29', DoubleType(), True), StructField('C30', DoubleType(), True), StructField('ADIC_REV_QTD', DoubleType(), True), StructField('ADIC_QTD', DoubleType(), True), StructField('ADIC_AGING_QTD', DoubleType(), True), StructField('ADIC_MUD_CALC_QTD', DoubleType(), True), StructField('ADIC_DEF_PARA_AC_QTD', DoubleType(), True), StructField('ADIC_EXEC_QTD', DoubleType(), True), StructField('ADIC_SOLV_PARA_INSOLV_QTD', DoubleType(), True), StructField('ADIC_MUD_FASE_QTD', DoubleType(), True), StructField('ADIC_FALTA_DOC_QTD', DoubleType(), True), StructField('ADIC_ENTR_NAOIDENT', DoubleType(), True), StructField('ADIC_COL_QTD', DoubleType(), True), StructField('ADIC_INSS_QTD', DoubleType(), True), StructField('REV_QTD', DoubleType(), True), StructField('REV_AGING_QTD', DoubleType(), True), StructField('REV_MUD_CALC_QTD', DoubleType(), True), StructField('REV_AC_VZ_PARA_DEF_QTD', DoubleType(), True), StructField('REV_EXEC_QTD', DoubleType(), True), StructField('REV_SOLV_PARA_INSOLV_QTD', DoubleType(), True), StructField('REV_MUD_FASE_QTD', DoubleType(), True), StructField('REV_INSS_QTD', DoubleType(), True), StructField('PGTO_QTD', DoubleType(), True), StructField('PGTO_QTD_AC', DoubleType(), True), StructField('PGTO_QTD_AC_PARC', DoubleType(), True), StructField('PGTO_QTD_COND', DoubleType(), True), StructField('PGTO_QTD_COND_PARC', DoubleType(), True), StructField('PGTO_QTD_LIB_DEP_JUD', DoubleType(), True), StructField('PGTO_QTD_PEN', DoubleType(), True), StructField('PGTO_QTD_IMP', DoubleType(), True), StructField('CRED_QTD', DoubleType(), True), StructField('CRED_CI_QTD', DoubleType(), True), StructField('CRED_OTH_GPA_QTD', DoubleType(), True), StructField('CRED_OTH_FK_QTD', DoubleType(), True), StructField('CRED_OTH_CNOVA_QTD', DoubleType(), True), StructField('CRED_TERCEIROS', DoubleType(), True), StructField('CRED_OTH_NAO_RECON_FK_QTD', DoubleType(), True), StructField('C66', DoubleType(), True), StructField('ENCERRADOS_QTD', DoubleType(), True), StructField('ENCERRADOS_NOVOS_QTD', DoubleType(), True), StructField('ENCERRADOS_LEGADO_QTD', DoubleType(), True), StructField('C70', DoubleType(), True), StructField('ENTR_VLR', DoubleType(), True), StructField('ENTR_NOVOS_VLR', DoubleType(), True), StructField('ENTR_REAT_VLR', DoubleType(), True), StructField('C74', DoubleType(), True), StructField('SAIDA_VLR', DoubleType(), True), StructField('SAIDA_SEM_ONUS_VLR', Doub ...

# %%
base_driver_trabalhista.write.format("delta") \
    .option("mergeSchema", "true") \
    .option("overwriteSchema", "true") \
    .mode("overwrite") \
    .saveAsTable(f"databox.juridico_comum.df_base_driver")

# %%
# import smtplib

# %%
# import smtplib
# from email.mime.multipart import MIMEMultipart
# from email.mime.text import MIMEText
# from email.mime.base import MIMEBase
# from email import encoders

# # Definir as configurações do servidor SMTP do Outlook
# smtp_server = "smtp.office365.com"
# smtp_port = 587

# # Credenciais do e-mail (use sua conta do Outlook)
# sender_email = "jefferson.rsilva@viavarejo.com.br"
# receiver_email = "jefferson.rsilva@viavarejo.com.br"
# password = "VIA@jeff1"  # Se necessário, utilize uma senha de aplicativo

# # Criar a mensagem de e-mail
# msg = MIMEMultipart()
# msg['From'] = sender_email
# msg['To'] = receiver_email
# msg['Subject'] = "Assunto do e-mail"

# # Corpo do e-mail
# body = "Aqui está o e-mail com o anexo."
# msg.attach(MIMEText(body, 'plain'))

# # Caminho do arquivo para anexar
# file_path = "/Volumes/databox/juridico_comum/arquivos/trabalhista/bases_indicadores_resultado/tb_inss_encerr_trab_202502_f.xlsx"

# # Adicionar o anexo
# attachment = open(file_path, "rb")
# part = MIMEBase('application', 'octet-stream')
# part.set_payload(attachment.read())
# encoders.encode_base64(part)
# part.add_header('Content-Disposition', f"attachment; filename={file_path.split('/')[-1]}")
# msg.attach(part)

# # Enviar o e-mail
# try:
#     server = smtplib.SMTP(smtp_server, smtp_port)
#     server.starttls()  # Ativar TLS
#     server.login(sender_email, password)  # Login no Outlook
#     text = msg.as_string()
#     server.sendmail(sender_email, receiver_email, text)  # Enviar o e-mail
#     print("E-mail enviado com sucesso!")
# except Exception as e:
#     print(f"Erro ao enviar e-mail: {e}")
# finally:
#     server.quit()
