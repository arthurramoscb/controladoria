# %% [markdown]
# # Tabela de Provisão Cível
#
#
# ####Tabela de Pagamentos Histórico Cível
# - **Outputs**\
# Tabela Delta:
#     df_fecham_civel_pbi

# %%
# %run "/Workspace/Jurídico/funcao_tratamento_fechamento/common_functions"

# %%
# Ler a tabela Delta
df_fecham_civel = spark.read.format("delta").table("databox.juridico_comum.tb_fech_civel_provisao")

df_fecham_civel = df_fecham_civel.fillna({
    "NOVOS": 0,
    "ENCERRADOS": 0,
    "ESTOQUE": 0
})

# Imprimir o schema
df_fecham_civel.write.format("delta") \
    .option("mergeSchema", "true") \
    .option("overwriteSchema", "true") \
    .mode("overwrite") \
    .saveAsTable(f"databox.juridico_comum.df_fecham_civel_pbi")
