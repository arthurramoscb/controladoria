# %% [markdown]
# ### ESSE APLICATIVO TEM COMO ONJETIVO TRAZER AS INFORMAÇÕES NECESSÁRIAS PARA PODER COMPARAR A QUANTIDADE DE PROCESSOS X COLBORADORES DESLIGADOS OU ATIVOS ###

# %%
#importar o normalizador para trazer todas as bibliotecas necessárias para a análise 
# %run "/Workspace/Jurídico/Normalizador_de_dados/Normalizador"

# %%
#carrega a tabela consolidada trabalhista da delta e transforma em um pandas df
df_trabalhista_consolidado = spark.table("databox.juridico_comum.Silver_Trabalhista_Gerencial").toPandas()

# %%
df_trabalhista_consolidado.shape
